# %%
Janet_age=55
Jennifer_age=22
Andy_age=25
print(Janet_age-Jennifer_age)
print(Janet_age-Andy_age)
# Out:
# 33
# 30

# %% [markdown]
# Calculates the different in ages between parent and two kids

# %%
diff = Janet_age-Jennifer_age
print(f"{diff} years old?") 
if diff <=18:
    print(f"years old? You are just a child yourself")
elif diff<=25:
    print("you are a young parent")
elif diff<=35:
    print("good age for a parent")
elif diff<=45:
    print("possibly high risk preganancy")
else:
    print("deffiniately a high risk preganancy")
# Out:
# 33 years old?
# good age for a parent

# %% [markdown]
# Prints the difference in age of parent and child,
# Then prints Janet's personal opinion on the age difference

# %%
for i in range(0,15,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 12

# %% [markdown]
# step by 3s from 0 to 15, not including 15 using range function
